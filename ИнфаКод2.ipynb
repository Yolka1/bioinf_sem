# %% [markdown]
# <a href="https://colab.research.google.com/github/Yolka1/bioinf_sem/blob/main/%D0%98%D0%BD%D1%84%D0%B0%D0%9A%D0%BE%D0%B42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
if a < 0:
  print ('Отрицательное')
elif a > 0:
  print ('Положительное')
else :
  print ('Это 0')
# Out:
# 4
# Положительное

# %%
a = int(input())
while a!=0:

  if a < 0:
   print ('Отрицательное')
  elif a > 0:
   print ('Положительное')
  a = int(input())

print ('Это 0')
# Out:
# 5
# Положительное
# -3
# Отрицательное
# 0
# Это 0

# %%
for i in range (1, 51):
  if i%2==0:
    print (i*2)
  else:
    print (i/3)
# Out:
# 0.3333333333333333
# 4
# 1.0
# 8
# 1.6666666666666667
# 12
# 2.3333333333333335
# 16
# 3.0
# 20
# 3.6666666666666665
# 24
# 4.333333333333333
# 28
# 5.0
# 32
# 5.666666666666667
# 36
# 6.333333333333333
# 40
# 7.0
# 44
# 7.666666666666667
# 48
# 8.333333333333334
# 52
# 9.0
# 56
# 9.666666666666666
# 60
# 10.333333333333334
# 64
# 11.0
# 68
# 11.666666666666666
# 72
# 12.333333333333334
# 76
# 13.0
# 80
# 13.666666666666666
# 84
# 14.333333333333334
# 88
# 15.0
# 92
# 15.666666666666666
# 96
# 16.333333333333332
# 100

# %%
import random
a = random.randint(1, 100)
for i in range (1,11):
  print (f'Попытка №{i}')
  b = int(input("Введите ваше число: "))

  if b > a:
    print ('Ваше число больше загаданного')
  elif a > b:
    print ('Ваше число меньше загаданного')
  else:
    print ('Вы угадали!')
    break

else:
  print (f'Вы проиграли! =( Было загадано: {a}')
# Out:
# Попытка №1
# Введите ваше число: 80
# Ваше число больше загаданного
# Попытка №2
# Введите ваше число: 40
# Ваше число меньше загаданного
# Попытка №3
# Введите ваше число: 60
# Ваше число больше загаданного
# Попытка №4
# Введите ваше число: 50
# Ваше число меньше загаданного
# Попытка №5
# Введите ваше число: 56
# Ваше число больше загаданного
# Попытка №6
# Введите ваше число: 52
# Ваше число больше загаданного
# Попытка №7
# Введите ваше число: 51
# Вы угадали!
